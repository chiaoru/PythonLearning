# %% [markdown]
# ppt
#
# canva https://www.canva.com/zh_tw/create/presentations/
#
# 螢幕錄影
#
# 訓練自己會講自己的作品與用意(對自己作品有一定的了解)
#
# 緣由/作品功能/運行結果/未來發展
#
# 六月徵才 --> 要報名
#
# 104更新

# %% [markdown]
# 辨識結果 ：水果、瓜果類、顏色、人臉等等，訓練完辨識，辨識結果是否是想要的
#
# 預測：股票，預測結果與實際是否相符
#
# 分析：辨識水果，為什麼黑白的辨識率低，彩色高，或什麼情形下比較高，做了什麼修正，如水果，在沒有色彩的情況下，很多圓形水果相似，另外如果將其他不相關的圖片元素拿掉時，辨識度會不會比較高
#
# 實價登錄整理分析-->統計

# %%
#
