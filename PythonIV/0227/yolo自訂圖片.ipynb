# %%
import glob
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ln -s /content/drive/MyDrive/2023聯成電腦/yolo/ /mydrive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# 載入yolo
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15833, done.
# remote: Total 15833 (delta 0), reused 0 (delta 0), pack-reused 15833
# Receiving objects: 100% (15833/15833), 14.39 MiB | 13.68 MiB/s, done.
# Resolving deltas: 100% (10666/10666), done.

# %%
# 切換到darknet資料夾
# %cd ./darknet
# Out:
# /content/darknet

# %%
# !cp cfg/yolov3.cfg cfg/yolov3_custom.cfg

# %%
# !sed -i 's/batch=1/batch=24/' cfg/yolov3_custom.cfg
# !sed -i 's/subdivisions=1/subdivision=16/' cfg/yolov3_custom.cfg
# !sed -i 's/max_batches = 500200/max_batches = 6000/' cfg/yolov3_custom.cfg
# 行數@種類更換
# !sed -i '610 s@classes=80@classes=3@' cfg/yolov3_custom.cfg
# !sed -i '696 s@classes=80@classes=3@' cfg/yolov3_custom.cfg
# !sed -i '783 s@classes=80@classes=3@' cfg/yolov3_custom.cfg
# filters計算方法 (C+5)B*3
# !sed -i '603 s@filters=255@filters=24@' cfg/yolov3_custom.cfg

# %%
# !mkdir data/obj

# %%
custom_obj = ['lipBalm', 'cow', 'maple']
# \n u 一行寫完就斷行
obj = '\n'.join(t for t in custom_obj)
with open('data/obj.names', 'w') as f:
  f.write(obj)

# %%
# 設定檔案資訊導向 data/obj.data
# !echo -e 'classes = 3\ntrain = data/train.txt\nvalid = data/test.txt\nnames = data/obj.names\nbackup = /content/drive/MyDrive/2023聯成電腦/yolo/' > data/obj.data

# %%
# 抓取圖片檔案
images_list = glob.glob('/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/0227/data/*[jpg|jpeg|png]')
print(images_list)
# Out:
# ['/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/0227/data/52.jpg', '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/0227/data/53.jpg', '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/0227/data/51.jpg', '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/0227/data/54.jpg', '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/0227/data/55.jpg', '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/0227/data/34.jpg', '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/0227/data/32.jpg', '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/0227/data/31.jpg', '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/0227/data/33.jpg', '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/0227/data/35.jpg', '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/0227/data/3.jpg', '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/0227/data/1.jpg', '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/0227/data/0.jpg', '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/0227/data/2
# ...

# %%
# 將檔案位置寫入train.txt
with open('data/train.txt', 'w') as f:
  f.write('\n'.join(images_list))

# %%
# 將檔案位置寫入test.txt
with open('data/test.txt', 'w') as f:
  f.write('\n'.join(images_list))

# %%
# 下載別人的權重，如果訓練東西不常見，可以不用別人的權重
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2024-02-27 14:22:52--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  35.3MB/s    in 6.5s
#
# 2024-02-27 14:24:06 (23.9 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !./darknet detector train data/obj.data cfg/yolov3_custom.cfg /content/darknet/darknet53.conv.74 -dont_show
# Out:
# /bin/bash: line 1: ./darknet: No such file or directory
