# %% [markdown]
# # 安裝人臉辨識函式庫

# %% [markdown]
# ! 代表開始下指令
#
# face-recognition 人臉辨識函式庫
#   * dlib 強大人臉辨識函式庫

# %%
# !pip install face-recognition
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 9.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566170 sha256=810ea99dda675d79c197d8b0bc8c6c0ee63392699985968bbf3a425043056990
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# ...

# %% [markdown]
# 載入人臉辨識與畫圖函式庫

# %%
import face_recognition
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw

# %% [markdown]
# 印出人臉座標 (元組)

# %%
fileName = '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/colab/image/onepublic.jpg'
image = face_recognition.load_image_file(fileName)
box = face_recognition.face_locations(image)
print(box)
# Out:
# [(53, 259, 115, 197), (39, 93, 101, 31), (87, 363, 149, 301), (108, 183, 170, 121), (87, 494, 149, 432), (53, 577, 115, 515)]

# %% [markdown]
# # 畫出人臉區塊

# %%
img = Image.open(fileName)
draw = ImageDraw.Draw(img)
for i in range(len(box)):
  draw.rectangle((box[i][3], box[i][0], box[i][1], box[i][2]), outline='red', width=2)
plt.imshow(img)
plt.show()

# %% [markdown]
# # 判斷是否為同一人

# %%
face1 = '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/colab/image/shon4.jpg'
face2 = '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/colab/image/shia3.jpg'
faceImg1 = face_recognition.load_image_file(face1)
faceImg2 = face_recognition.load_image_file(face2)
know_face = face_recognition.face_encodings(faceImg1)
test_face = face_recognition.face_encodings(faceImg2)
know_face
# Out:
# [array([-0.06365822,  0.09016746, -0.00229052, -0.0431715 , -0.09796024,
#         -0.02285754, -0.04137947, -0.04430518,  0.19284451, -0.0876876 ,
#          0.18042812, -0.06954754, -0.18495069, -0.02232429, -0.01755743,
#          0.1874457 , -0.21599934, -0.16641341, -0.02918775,  0.06260489,
#          0.15958399,  0.01561981,  0.00881544,  0.10614277, -0.14333461,
#         -0.34310669, -0.05544864, -0.09633522, -0.0241373 , -0.09217298,
#         -0.00773766,  0.06183875, -0.20703679, -0.04076667,  0.01630438,
#          0.11257592, -0.00708106, -0.08196825,  0.18226765, -0.00991556,
#         -0.37273887,  0.05733658,  0.06629369,  0.22439082,  0.17650504,
#          0.02310953, -0.01256694, -0.11433469,  0.10247   , -0.19893199,
#          0.03575543,  0.15130921,  0.05018619,  0.05627232,  0.01359445,
#         -0.11194887,  0.06666917,  0.09957355, -0.15409756, -0.04665708,
#          0.11231145, -0.04732212,  0.08270893, -0.05954254,  0.20481193,
# ...

# %%
know_face[0]
# Out:
# array([-0.06365822,  0.09016746, -0.00229052, -0.0431715 , -0.09796024,
#        -0.02285754, -0.04137947, -0.04430518,  0.19284451, -0.0876876 ,
#         0.18042812, -0.06954754, -0.18495069, -0.02232429, -0.01755743,
#         0.1874457 , -0.21599934, -0.16641341, -0.02918775,  0.06260489,
#         0.15958399,  0.01561981,  0.00881544,  0.10614277, -0.14333461,
#        -0.34310669, -0.05544864, -0.09633522, -0.0241373 , -0.09217298,
#        -0.00773766,  0.06183875, -0.20703679, -0.04076667,  0.01630438,
#         0.11257592, -0.00708106, -0.08196825,  0.18226765, -0.00991556,
#        -0.37273887,  0.05733658,  0.06629369,  0.22439082,  0.17650504,
#         0.02310953, -0.01256694, -0.11433469,  0.10247   , -0.19893199,
#         0.03575543,  0.15130921,  0.05018619,  0.05627232,  0.01359445,
#        -0.11194887,  0.06666917,  0.09957355, -0.15409756, -0.04665708,
#         0.11231145, -0.04732212,  0.08270893, -0.05954254,  0.20481193,
# ...

# %% [markdown]
# 測人臉距離
#
# 東方人 < 0.4
#
# 外國人 < 0.6

# %%
face_distance = face_recognition.face_distance([know_face[0]],test_face[0])
face_distance
# Out:
# array([0.44434032])

# %% [markdown]
# 多個人臉辨識

# %%
person1 = '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/colab/image/shon4.jpg'
person2 = '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/colab/image/lai2.jpg'
person3 = '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/colab/image/shia2.jpg'
person4 = '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/colab/image/qe.jpg'
person5 = '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/colab/image/chen.jpg'
# 名字需依序放入
names = ['宋芸樺', '賴清德', '夏宇喬', '柯文哲', '陳水扁']

pImg1 = face_recognition.load_image_file(person1)
pImg2 = face_recognition.load_image_file(person2)
pImg3 = face_recognition.load_image_file(person3)
pImg4 = face_recognition.load_image_file(person4)
pImg5 = face_recognition.load_image_file(person5)

encoding1 = face_recognition.face_encodings(pImg1)[0]
encoding2 = face_recognition.face_encodings(pImg2)[0]
encoding3 = face_recognition.face_encodings(pImg3)[0]
encoding4 = face_recognition.face_encodings(pImg4)[0]
encoding5 = face_recognition.face_encodings(pImg5)[0]
know_faces = [encoding1, encoding2, encoding3, encoding4, encoding5]

# %%
# 人臉比較
result = face_recognition.compare_faces(know_faces, encoding4, 0.4)
result
# Out:
# [False, False, False, True, False]

# %%
testPerson = '/content/drive/MyDrive/2023聯成電腦/Python IV 視覺辨識與機器學習/colab/image/chen2.jpg'
testImg = face_recognition.load_image_file(testPerson)
testEncoding = face_recognition.face_encodings(testImg)[0]

testResult = face_recognition.compare_faces(know_faces, testEncoding, 0.4)
testResult
# Out:
# [False, False, False, False, False]

# %%
# 抓出人臉是誰
faceName = ''
for i in range(len(result)):
  # result 是布林值，True時進來
  if result[i]:
    # 找到True相對位置的名字
    faceName += names[i]+","

if faceName == '':
  print('查無此人!')
else:
  print(faceName)
# Out:
# 柯文哲,

# %%
images = face_recognition.face_landmarks(pImg1)
images
# Out:
# [{'chin': [(444, 191),
#    (451, 213),
#    (458, 234),
#    (469, 254),
#    (484, 269),
#    (503, 280),
#    (525, 287),
#    (547, 290),
#    (567, 287),
#    (583, 280),
#    (592, 266),
#    (599, 249),
#    (603, 231),
#    (606, 214),
#    (608, 196),
#    (607, 179),
#    (602, 163)],
#   'left_eyebrow': [(472, 156), (482, 144), (498, 138), (515, 137), (531, 140)],
#   'right_eyebrow': [(556, 138),
#    (566, 131),
#    (578, 128),
#    (589, 129),
#    (597, 136)],
#   'nose_bridge': [(549, 158), (553, 169), (557, 180), (562, 192)],
#   'nose_tip': [(546, 210), (554, 211), (561, 210), (567, 208), (571, 205)],
#   'left_eye': [(492, 172),
#    (502, 164),
#    (513, 162),
#    (524, 169),
#    (514, 172),
#    (503, 174)],
#   'right_eye': [(565, 163),
#    (573, 154),
#    (583, 153),
#    (590, 159),
#    (585, 162),
#    (575, 163)],
#   'top_lip': [(531, 244),
#    (545, 234),
#    (557, 226),
#    (564, 227),
#    (570, 224),
#    (578, 228),
#    (585, 235),
# ...

# %% [markdown]
# 程式碼片段搜尋 Camera Capture
#
# 將程式碼掛進來

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))

  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))


testf = filentestImg = face_recognition.load_image_file(testPerson)
testencoding = face_recognition.face_encodings(testImg)[0]
testresult = face_recognition.compare_faces(know_faces, testencoding, 0.4)
facename = ''
for i in range(len(testresult)):
  # result 是布林值，True時進來
  if result[i]:
    # 找到True相對位置的名字
    facename += names[i]+","

if facename == '':
  print('查無此人!')
else:
  print(facename)
# Out:
# NotFoundError: Requested device not found
# 柯文哲,

# %% [markdown]
# ### 12/28

# %% [markdown]
# pip install --user cvzone
#
# pip install mediapipe
